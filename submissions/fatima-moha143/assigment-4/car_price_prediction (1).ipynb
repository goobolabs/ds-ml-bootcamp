# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# Part B — Practical: Car Price Prediction

# %% [markdown]
# 1.Load Dataset

# %%
import os

CSV_PATH="clean_car_dataset.csv"
print(os.getcwd())  # Check current working directory
print(os.listdir())  # List files in current directory

# If the file is in a different location, update CSV_PATH accordingly
df = pd.read_csv(CSV_PATH)
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 2
#       1 CSV_PATH="clean_car_dataset.csv"
# ----> 2 df=pd.read_csv(CSV_PATH)
#       3 print(df.head())
#
# File c:\Users\FATMA\OneDrive\Desktop\ds-ml-bootcamp\.venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
# ...

# %% [markdown]
# 2-Prepare Features & Target

# %%
x=df.drop(columns=["Price", "LogPrice"])
y=df["Price"]

# %% [markdown]
# 3-Split Data

# %%
x_train, x_test, y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %% [markdown]
# 4-Train Models

# %% [markdown]
# Train Linear Regression Predivtions

# %%
lr=LinearRegression()
lr.fit(x_train, y_train)
lr_pred=lr.predict(x_test)

# %%
print("Linear Regression Predictions: ")
print(lr_pred)
# Out:
# Linear Regression Predictions:
# [4899.50736001 5224.73318108 2847.81938143 5475.57747211  520.7249123
#  4934.56577747 1851.08736106 2862.5209127  2701.74874827   72.16482488
#  5264.78444252 2802.56895103 2779.92481519 6087.39781519 3947.12066312
#  3878.19384015 6405.81217655 4459.59601218 3199.69302721 1454.98609089
#  5881.95600965 1418.74474713  149.76386792 5568.17893029 3244.59513295
#   878.9864125  1764.94905515 1372.04434147]

# %% [markdown]
# Train RandomForestRegressor

# %%
rf=RandomForestRegressor(n_estimators=100, random_state=42 )

# %%
rf.fit(x_train, y_train)
rf_pred=rf.predict(x_test)

# %%
print("Random Forest Predictions: ")
print(rf_pred)
# Out:
# Random Forest Predictions:
# [4477.80125 7462.11625 1910.43    6336.3225  1500.      3660.16375
#  1500.      1747.46    1500.      1729.87    6873.935   1527.72
#  1500.      7580.47875 4757.58125 1644.8     6936.405   6518.2425
#  1543.88    1831.61    6829.5025  1537.38    1808.34    7356.115
#  5484.915   2559.3     1512.46    1500.     ]

# %% [markdown]
# 5-Evaluate Performance

# %%
def print_metrics(name,y_true, y_pred):
    r2=r2_score(y_true, y_pred)
    mae= mean_absolute_error(y_true, y_pred)
    mse=mean_squared_error(y_true, y_pred)
    rmse=np.sqrt(mse)
    print(f"{name} Performance:")
    print(f"  R²   :{r2:.3f} ")
    print(f" MAE   : {mae:,.0f}")
    print(f" MSE   : {mse:,.0f}")
    print(f" RMSE  : {rmse:,.0f}")

# %%
print_metrics("Linear Regression" , y_test,lr_pred)
print_metrics("Random Forest", y_test, rf_pred)
# Out:
# Linear Regression Performance:
#   R²   :0.406
#  MAE   : 1,444
#  MSE   : 3,950,659
#  RMSE  : 1,988
# Random Forest Performance:
#   R²   :0.323
#  MAE   : 1,182
#  MSE   : 4,503,864
#  RMSE  : 2,122

# %% [markdown]
# 6-Sanity Check

# %%
i=3
x_one_df= x_test.iloc[[i]]
y_true=y_test.iloc[i]

# %%
p_lr_one=float(lr.predict(x_one_df)[0])
p_rf_one=float(rf.predict(x_one_df)[0])

# %%
print("Single-row sanity check: ")
print(f"Actual Price : ${y_true: ,.0f}")
print(f"Linear Regression Predictions : ${p_lr_one: ,.0f}")
print(f"Random Forest Prediction : ${p_rf_one: ,.0f}")
# Out:
# Single-row sanity check:
# Actual Price : $ 7,009
# Linear Regression Predictions : $ 5,476
# Random Forest Prediction : $ 6,336
